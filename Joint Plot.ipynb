# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df =pd.read_csv('tips.csv')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df1 =pd.read_csv('iris.csv')

# %%
df1.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
sns.jointplot(x= 'total_bill', y ='tip', data=df)

# %%
# here we have sctter plot between two variables and marginal distribution is shown  besides

# %%
sns.jointplot(x= 'SepalLengthCm', y ='SepalWidthCm', data=df1)

# %%
sns.jointplot(x= 'total_bill', y ='tip', data=df, kind= 'reg')

# %%
# kind= reg add regression lines to lot and gives kernal density to scatter plot

# %%
sns.jointplot(x= 'total_bill', y ='tip', data=df, color= 'red')
